# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
phi=np.linspace(-5,5,100)
for p in phi:
    for a in range(1,4):
        r=a/2+np.cos(p)
        plt.plot(r*np.cos(p), r*np.sin(p), '.', color='black')
